# %%
from bizarre import *

reset_team()

TEAM['GIRLS'] = {
    'Lucifer': 1,  # <Girl's name>: <her current level>
    # 'Michael': 1, # Comment the girls you don't have, or change the level to 0
    'Dracula': 0,  # Like this
    # 'Saint': 1,
    # 'Nobunaga': 1,
    'KongMing': 1,
    # 'Marynari': 1,
    'Robin': 1,
    'Sisha': 1,
    'Mythra': 1,
    'Athena': 1,
    # 'Kenshin': 1,
    # 'Reo': 1,
    # 'Poppi': 1,
    'Jade': 1,
    'Ursula': 1,
    'Kitty': 1,
    'Samurai': 1,
    # 'Tula': 1,
    'Edward': 1,
    'King': 1,
    'Donna': 1,
    'Nobuna': 1,
    'Annabelle': 1,
    'Harley': 1,
    'Magician': 1,
    'Caitlin': 1
}

TEAM['VE'] = 484  # Current VE obtained
TEAM['STAGE'] = 1  # Current stage
TEAM['MAP'] = (5, 1)  # Number of monsters and bosses in the current stage
read_team(TEAM)

GOAL = 28  # Goal stage
calc(GOAL)  # Number of VE required to pass the goal stage
check_fin(GOAL)  # Optimal upgrading during the exploration
# Out:
# Range: 0 512
# Range: 0 256
# Range: 128 256
# Range: 192 256
# Range: 224 256
# Range: 224 240
# Range: 232 240
# Range: 232 236
# Range: 234 236
# Range: 234 235
# Range: 156 235
# Range: 195 235
# Range: 215 235
# Range: 225 235
# Range: 230 235
# Range: 230 232
# Range: 231 232
#
# You need 232 more VE to pass Stage 28 (3116 in total).
# Levels:
# 	Lucifer:     	17
# 	KongMing:     	9
# 	Robin:     	38
# 	Sisha:     	40
# 	Mythra:     	40
# 	Athena:     	40
#
# Stage 27: WIN
# Levels:
# 	Lucifer:     	14
# 	KongMing:     	9
# 	Robin:     	38
# 	Sisha:     	40
# 	Mythra:     	40
# 	Athena:     	40
#
# Stage 26: WIN
# Levels:
# 	Lucifer:     	12
# 	KongMing:     	9
# 	Robin:     	38
# 	Sisha:     	40
# 	Mythra:     	40
# 	Athena:     	40
#
# Stage 25: WIN
# Levels:
# 	Lucifer:     	10
# 	KongMing:     	9
# 	Robin:     	38
# 	Sisha:     	40
# 	Mythra:     	40
# 	Athena:     	40
#
# Stage 24: WIN
# Levels:
# 	Lucifer:     	10
# 	KongMing:     	8
# 	Robin:     	38
# 	Sisha:     	37
# ...
